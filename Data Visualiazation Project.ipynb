# %% [markdown]
# # Titanic Data Visualiazation Project

# %%
import pandas as pd
titanic = pd.read_csv('C:/Users/hp/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
titanic.tail(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# ...

# %% [markdown]
# # Finding Unique Values

# %%
titanic['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
m1 = titanic['Age'].median()
m2=int(m1)
m2
# Out:
# 28

# %%
m1 = titanic['Age'].median(skipna=True)
m2 = titanic['Age'].mean(skipna=True)
print(m1)
print(m2)
# Out:
# 28.0
# 29.69911764705882

# %% [markdown]
# # count missing values in age

# %%
a = sum(pd.isnull(titanic['Age']))
a
# Out:
# 177

# %% [markdown]
# # proportion of 'Age' missing in percent

# %%
length =len(titanic['PassengerId'])
print(length)
b = a/length*100
b
# Out:
# 891
# 19.865319865319865

# %%
na_age=titanic['Age'].notna()
print(na_age.count())
# Out:
# 891

# %%
titanic_copy = titanic

# %%
titanic_copy['Age'].fillna(28,inplace=True)
titanic_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_copy['Age'].fillna(28,inplace=True)
titanic_copy['Embarked'].fillna('s',inplace=True)
titanic_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

y2 = titanic_copy['Age']
x2 = np.arange(len(y2))

plt.plot(x2,y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

y2 = titanic_copy['Age']
x2 = np.arange(len(y2))

plt.plot(x2,y2)
plt.show()

sns.lineplot(data=titanic_copy,x='Survived', y="Age")
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
survived_mean = titanic_copy.query('Survived>0')
print(survived_mean['Age'].mean())
# Out:
# 28.29143274853801

# %%
not_survived_mean = titanic_copy.query('Survived==0')
print(not_survived_mean['Age'].mean())
# Out:
# 30.028233151183972

# %%
sns.lineplot(x='Embarked',y='Age',hue='Survived',data=titanic)
# Out:
# <Axes: xlabel='Embarked', ylabel='Age'>

# %%
category_order = ['S','C','Q']
sns.catplot(data=titanic,x='Embarked',order=category_order,kind='count',palette=['orange','green','hotpink'])
plt.show()

# %%
sns.barplot(data=titanic,x='Survived',y='Age',palette=['orange','green'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.set_theme()

titanic_copy=[titanic]
for dataset in titanic_copy:
    mean = titanic['Age'].mean()
    std = titanic['Age'].std()
    is_null = dataset['Age'].isnull().sum()
    #compute mean, std and is null random number
    rand_age = np.random.randint(mean-std,mean+std,size=is_null)
    #fill nan values in age column with random values generated
    
    age_slice = dataset['Age'].copy()
    age_slice[np.isnan(age_slice)]=rand_age
    dataset['Age']=age_slice
    dataset['Age']=titanic['Age'].astype(int)

# %%
survived = 'Survived'
not_survived = 'not Survived'
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(16,8))
women = titanic[titanic['Sex']=='female']
men = titanic[titanic['Sex']=='male']

ax = sns.distplot(women[women['Survived']==1].Age.dropna(),bins=18,label=survived,ax=axes[0],kde=False,color='green')
ax = sns.distplot(women[women['Survived']==0].Age.dropna(),bins=18,label=not_survived,ax=axes[0],kde=False,color='green')
ax.legend()
ax.set_title('female')

ax = sns.distplot(men[men['Survived']==1].Age.dropna(),bins=18,label=survived,ax=axes[1],kde=False,color='orange')
ax = sns.distplot(men[men['Survived']==0].Age.dropna(),bins=18,label=not_survived,ax=axes[1],kde=False,color='orange')
ax.legend()
ax.set_title('Male')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2996\2778891953.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(women[women['Survived']==1].Age.dropna(),bins=18,label=survived,ax=axes[0],kde=False,color='green')
# C:\Users\hp\AppData\Local\Temp\ipykernel_2996\2778891953.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...
